# %%
import pandas as pd
import requests

# %%
url='https://www.worldcoinindex.com/'
crypto_url=requests.get(url)
crypto_url
# Out:
# <Response [200]>

# %%
body=crypto_url.text

# %%
body
# Out:
# '\n<!DOCTYPE html>\n<html style="background-color: #FFF">\n<head>\n<meta http-equiv="Content-Type" content="text/html">\n<meta name="mobile-web-app-capable" content="yes">\n<meta charset="utf-8" />\n<meta name="description" content="Cryptocoins ranked by 24hr trading volume, price info, charts, market cap and news" />\n<meta name="keywords" content="Coin, index, worldcoin, coinindex, worldindex, cryptocoins, crypto, traded, exchanges, ranked, marketcap, coins, cryptocurrency ,coinprices, price, last trade time, trade, market cap, trading, traded, volume, rate, buy cryptocurrency, sell cryptocurrency" />\n<meta name="viewport" content="width=device-width, initial-scale=1, user-scalable = no">\n<meta name="apple-mobile-web-app-capable" content="yes" />\n<meta name="propeller" content="efad6eed15cdd45139ef34d287cc06ff" />\n<meta property="og:image" content="https://www.worldcoinindex.com/content/img/worldcoinindex_social.png?v=3" />\n<title>Cryptocoin price index and market cap - WorldCoinIndex</title>\n<link rel="manifest" href="/manifest.json?v=4">\n<link rel="icon" href="/favicon.ico?v=3" />\n<link rel="stylesheet" type="text/css" href="https://fonts.googleapis.com/css?family=Ubuntu:regular,bold&subset=Latin">\n<link href="/content/css/v-637249444541183387/bootstrap.css" rel="stylesheet">\n<link href="/content/css/v-637487397733033263/wcicombined.css" rel="stylesheet">\n<link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.13.0/css/all.css" integrity="sha384-Bfad6CLCknfcloXFOyFnlgtENryhrpZCe29RTifKEixXQZ38WheV+i/6YWSzkz3V" crossorigin="anonymous">\n<link rel="alternate" hreflang="en" href="https://www.worldcoinindex.com">\n<link rel="alternate" hreflang="id" href="https://www.worldcoinindex.com/id">\n<link rel="alternate" hreflang="ms" href="https://www.worldcoinindex.com/ms">\n<link rel="alternate" hreflang="da" href="https://www.worldcoinindex.com/da">\n<link rel="alternate" hreflang="de" href="https://www.worldcoinindex.com/de">\n<link rel="alternate" hreflang="es" href="https://www.worldcoinindex.com/es">\n<link rel="alternate" hreflang="ph" href="https://www.worldcoinindex.com/ph">\n<link rel="alternate" hreflang="fr" href="https://www.worldcoinindex.com/fr">\n<link rel="alternate" hreflang="it" href="https://www.worldcoinindex.com/it">\n<link rel="alternate" hreflang="hu" href="https://www.worldcoinindex.com/hu">\n<link rel="alternate" hreflang="nl" href="https://www.worldcoinindex.com/nl">\n<link rel="alternate" hreflang="no" href="https://www.worldcoinindex.com/no">\n<link rel="alternate" hreflang="pl" href="https://www.worldcoinindex.com/pl">\n<link rel="alternate" hreflang="pt" href="https://www.worldcoinindex.com/pt">\n<link rel="alternate" hreflang="ro" href="https://www.worldcoinindex.com/ro">\n<link rel="alternate" hreflang="sl" href="https://www.worldcoinindex.com/sl">\n<link rel="alternate" hreflang="fi" href="https://www.worldcoinindex.com/fi">\n<link rel="alternate" hreflang="sw" href="https://www.worldcoinindex.com/sw">\n<link rel="alternate" hreflang="vi" href="https://www.worldcoinindex.com/vi">\n<link rel="alternate" hreflang="tr" href="https://www.worldcoinindex.com/tr">\n<link rel="alternate" hreflang="el" href="https://www.worldcoinindex.com/el">\n<link rel="alternate" hreflang="bg" href="https://www.worldcoinindex.com/bg">\n<link rel="alternate" hreflang="ru" href="https://www.worldcoinindex.com/ru">\n<link rel="alternate" hreflang="ar" href="https://www.worldcoinindex.com/ar">\n<link rel="alternate" hreflang="hi" href="https://www.worldcoinindex.com/hi">\n<link rel="alternate" hreflang="bn" href="https://www.worldcoinindex.com/bn">\n<link rel="alternate" hreflang="th" href="https://www.worldcoinindex.com/th">\n<link rel="alternate" hreflang="ko" href="https://www.worldcoinindex.com/ko">\n<link rel="alternate" hreflang="zh" href="https://www.worldcoinindex.com/zh">\n<link rel="alternate" hreflang="ja" href="https://www.worldcoinindex.com/ja">\n<link rel="canonical" href="https://www.wor ...

# %%
crypto_data=pd.read_html(body)
print(type(crypto_data))
print(len(crypto_data))
# Out:
# <class 'list'>
# 1

# %%
crypto_data=crypto_data[0]
crypto_data.head()
# Out:
#    # Unnamed: 1         Name Ticker  Last price       %     24 high  \
# 0  1        NaN      Bitcoin    BTC    $ 56,160  +0.41%    $ 56,458
# 1  2        NaN     Ethereum    ETH  $ 1,793.40  -0.29%  $ 1,805.93
# 2  3        NaN     Litecoin    LTC    $ 199.94  -0.26%    $ 202.01
# 3  4        NaN  Binancecoin    BNB    $ 282.57  +1.34%    $ 284.65
# 4  5        NaN     Polkadot    DOT     $ 37.21  -0.85%     $ 37.93
#
#        24 low Price Charts 7d 24 volume  # Coins Market cap
# 0    $ 55,204             NaN  $ 23.18B   18.64M    $ 1.04T
# 1  $ 1,765.38             NaN  $ 12.30B  114.99M  $ 206.24B
# 2    $ 196.36             NaN   $ 2.83B   66.62M   $ 13.32B
# 3    $ 275.61             NaN   $ 2.26B   99.01M   $ 27.97B
# 4     $ 36.55             NaN   $ 1.55B  947.85M   $ 35.26B

# %%
import requests

# %%
page=requests.get('http://dataquestio.github.io/web-scraping-pages/simple.html')
page
# Out:
# <Response [200]>

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html>\n    <head>\n        <title>A simple example page</title>\n    </head>\n    <body>\n        <p>Here is some simple content for this page.</p>\n    </body>\n</html>'

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    A simple example page
#   </title>
#  </head>
#  <body>
#   <p>
#    Here is some simple content for this page.
#   </p>
#  </body>
# </html>

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html>
#  <head>
#  <title>A simple example page</title>
#  </head>
#  <body>
#  <p>Here is some simple content for this page.</p>
#  </body>
#  </html>]

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype, bs4.element.NavigableString, bs4.element.Tag]

# %%
html=list(soup.children)[2]

# %%
html
# Out:
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# </html>

# %%
list(html.children)
# Out:
# ['\n',
#  <head>
#  <title>A simple example page</title>
#  </head>,
#  '\n',
#  <body>
#  <p>Here is some simple content for this page.</p>
#  </body>,
#  '\n']

# %%
body=list(html.children)[3]
body
# Out:
# <body>
# <p>Here is some simple content for this page.</p>
# </body>

# %%
list(body.children)
# Out:
# ['\n', <p>Here is some simple content for this page.</p>, '\n']

# %%
p=list(body.children)[1]

# %%
p
# Out:
# <p>Here is some simple content for this page.</p>

# %% [markdown]
# ### Finding all instances of a tag at once

# %%
soup=BeautifulSoup(page.content, 'html.parser')
soup.find_all('p')
# Out:
# [<p>Here is some simple content for this page.</p>]

# %%
soup.find_all('p')[0].get_text()
# Out:
# 'Here is some simple content for this page.'

# %%
soup.find('p')
# Out:
# <p>Here is some simple content for this page.</p>

# %%
page = requests.get("http://dataquestio.github.io/web-scraping-pages/ids_and_classes.html")
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 First paragraph.
#             </p>
# <p class="inner-text">
#                 Second paragraph.
#             </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 First outer paragraph.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 Second outer paragraph.
#             </b>
# </p>
# </body>
# </html>

# %%
soup.find_all('p')[0].get_text()
# Out:
# '\n                First paragraph.\n            '

# %%
soup.find_all('p', class_='outer-text')
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  First outer paragraph.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  Second outer paragraph.
#              </b>
#  </p>]

# %%
soup.find_all(class_='outer-text')
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  First outer paragraph.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  Second outer paragraph.
#              </b>
#  </p>]

# %%
soup.find_all(id='first')
# Out:
# [<p class="inner-text first-item" id="first">
#                  First paragraph.
#              </p>]

# %%
page = requests.get("http://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168")
soup = BeautifulSoup(page.content, 'html.parser')
seven_day = soup.find(id="seven-day-forecast")
forecast_items = seven_day.find_all(class_="tombstone-container")
tonight = forecast_items[0]
print(tonight.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   Tonight
#   <br/>
#   <br/>
#  </p>
#  <p>
#   <img alt="Tonight: A 30 percent chance of rain, mainly before 10pm.  Partly cloudy, with a low around 43. Southeast wind 5 to 9 mph becoming calm  after midnight. " class="forecast-icon" src="newimages/medium/nra30.png" title="Tonight: A 30 percent chance of rain, mainly before 10pm.  Partly cloudy, with a low around 43. Southeast wind 5 to 9 mph becoming calm  after midnight. "/>
#  </p>
#  <p class="short-desc">
#   Chance Rain
#  </p>
#  <p class="temp temp-low">
#   Low: 43 °F
#  </p>
# </div>

# %%
period = tonight.find(class_="period-name").get_text()
short_desc = tonight.find(class_="short-desc").get_text()
temp = tonight.find(class_="temp").get_text()
print(period)
print(short_desc)
print(temp)
# Out:
# Tonight
# Chance Rain
# Low: 43 °F

# %%
img = tonight.find("img")
desc = img['title']
print(desc)
# Out:
# Tonight: A 30 percent chance of rain, mainly before 10pm.  Partly cloudy, with a low around 43. Southeast wind 5 to 9 mph becoming calm  after midnight.

# %%
period_tags=seven_day.select('.tombstone-container .period-name')
periods=[pt.get_text() for pt in period_tags]
periods
# Out:
# ['Tonight',
#  'Thursday',
#  'ThursdayNight',
#  'Friday',
#  'FridayNight',
#  'Saturday',
#  'SaturdayNight',
#  'Sunday',
#  'SundayNight']

# %%
short_descs=[sd.get_text() for sd in seven_day.select('.tombstone-container .short-desc')]
temps=[t.get_text() for t in seven_day.select('.tombstone-container .temp')]
descs=[d['title'] for d in seven_day.select('.tombstone-container img')]
print(short_descs)
print(temps)
print(descs)
# Out:
# ['Chance Rain', 'Sunny', 'Mostly Clear', 'Sunny', 'Mostly Clear', 'Mostly Sunny', 'Slight ChanceRain', 'Chance Rain', 'Chance Rain']
# ['Low: 43 °F', 'High: 58 °F', 'Low: 44 °F', 'High: 62 °F', 'Low: 45 °F', 'High: 60 °F', 'Low: 46 °F', 'High: 58 °F', 'Low: 45 °F']
# ['Tonight: A 30 percent chance of rain, mainly before 10pm.  Partly cloudy, with a low around 43. Southeast wind 5 to 9 mph becoming calm  after midnight. ', 'Thursday: Sunny, with a high near 58. North wind 6 to 9 mph becoming west in the afternoon. ', 'Thursday Night: Mostly clear, with a low around 44. West wind 5 to 8 mph becoming calm  after midnight. ', 'Friday: Sunny, with a high near 62. Light and variable wind becoming west 8 to 13 mph in the afternoon. ', 'Friday Night: Mostly clear, with a low around 45. West wind 10 to 14 mph. ', 'Saturday: Mostly sunny, with a high near 60.', 'Saturday Night: A 20 percent chance of rain after 10pm.  Mostly cloudy, with a low around 46.', 'Sunday: A chance of rain.  Mostly cloudy, with a high near 58.', 'Sunday Night: A chance of rain before 4am.  Mostly cloudy, with a low around 45.']

# %%
import pandas as pd
weather=pd.DataFrame({
    "period":periods,
    'short_descs':short_descs,
    'temp':temps,
    'desc': descs
})

weather
# Out:
#           period        short_descs         temp  \
# 0        Tonight        Chance Rain   Low: 43 °F
# 1       Thursday              Sunny  High: 58 °F
# 2  ThursdayNight       Mostly Clear   Low: 44 °F
# 3         Friday              Sunny  High: 62 °F
# 4    FridayNight       Mostly Clear   Low: 45 °F
# 5       Saturday       Mostly Sunny  High: 60 °F
# 6  SaturdayNight  Slight ChanceRain   Low: 46 °F
# 7         Sunday        Chance Rain  High: 58 °F
# 8    SundayNight        Chance Rain   Low: 45 °F
#
#                                                 desc
# 0  Tonight: A 30 percent chance of rain, mainly b...
# 1  Thursday: Sunny, with a high near 58. North wi...
# 2  Thursday Night: Mostly clear, with a low aroun...
# 3  Friday: Sunny, with a high near 62. Light and ...
# 4  Friday Night: Mostly clear, with a low around ...
# 5       Saturday: Mostly sunny, with a high near 60.
# 6  Saturday Night: A 20 percent chance of rain af...
# 7  Sunday: A chance of rain.  Mostly cloudy, with...
# 8  Sunday Night: A chance of rain before 4am.  Mo...
