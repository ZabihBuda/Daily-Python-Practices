# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
import numpy as np

# %%
world_json=pd.read_json('world_bank_projects.json')
world_json.head(4)
# Out:
#                                               sector supplementprojectflg  \
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
# 2  [{'Name': 'Rural and Inter-Urban Roads and Hig...                    Y
# 3                [{'Name': 'Other social services'}]                    N
#
#   projectfinancialtype prodline  \
# 0                  IDA       PE
# 1                OTHER       RE
# 2                  IDA       PE
# 3                OTHER       RE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 1  [Economic management, Social protection and ri...           0
# 2  [Trade and integration, Public sector governan...     6060000
# 3  [Social dev/gender/inclusion, Social dev/gende...           0
#
#                                   impagency  \
# 0                     MINISTRY OF EDUCATION
# ...

# %% [markdown]
# ### 1: Find the 10 countries with most projects

# %%
projects=world_json.groupby('countryname').count()
projects.head(3)
# Out:
#                         sector  supplementprojectflg  projectfinancialtype  \
# countryname
# Africa                      11                    11                    11
# Antigua and Barbuda          1                     1                     1
# Arab Republic of Egypt       2                     2                     2
#
#                         prodline  mjtheme  idacommamt  impagency  \
# countryname
# Africa                        11       11          11          8
# Antigua and Barbuda            1        1           1          1
# Arab Republic of Egypt         2        2           2          2
#
#                         project_name  mjthemecode  closingdate  ...  sector3  \
# countryname                                                     ...
# Africa                            11           11            7  ...        7
# Antigua and Barbuda                1            1            1  ...        1
# ...

# %%
top_countries=projects.sort_values(by='project_name', ascending=False)
top_countries['project_name'].head(10)
# Out:
# countryname
# People's Republic of China         19
# Republic of Indonesia              19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# People's Republic of Bangladesh    12
# Nepal                              12
# Kingdom of Morocco                 12
# Republic of Mozambique             11
# Africa                             11
# Name: project_name, dtype: int64

# %% [markdown]
# ### 2: What are top 10 sectors with projects?

# %%
pd.DataFrame(world_json['sector'])
# Out:
#                                                 sector
# 0    [{'Name': 'Primary education'}, {'Name': 'Seco...
# 1    [{'Name': 'Public administration- Other social...
# 2    [{'Name': 'Rural and Inter-Urban Roads and Hig...
# 3                  [{'Name': 'Other social services'}]
# 4    [{'Name': 'General industry and trade sector'}...
# ..                                                 ...
# 495  [{'Name': 'General agriculture, fishing and fo...
# 496  [{'Name': 'Central government administration'}...
# 497  [{'Name': 'Irrigation and drainage'}, {'Name':...
# 498  [{'Name': 'Agricultural extension and research...
# 499  [{'Name': 'Urban Transport'}, {'Name': 'Public...
#
# [500 rows x 1 columns]

# %%
project_sector=world_json.explode('sector')
project_sector.head()
# Out:
#                                               sector supplementprojectflg  \
# 0                      {'Name': 'Primary education'}                    N
# 0                    {'Name': 'Secondary education'}                    N
# 0  {'Name': 'Public administration- Other social ...                    N
# 0                     {'Name': 'Tertiary education'}                    N
# 1  {'Name': 'Public administration- Other social ...                    N
#
#   projectfinancialtype prodline  \
# 0                  IDA       PE
# 0                  IDA       PE
# 0                  IDA       PE
# 0                  IDA       PE
# 1                OTHER       RE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 0                                [Human development]   130000000
# 0                                [Human development]   130000000
# ...

# %%
sector_series = project_sector['sector']
sector_series
# Out:
# 0                          {'Name': 'Primary education'}
# 0                        {'Name': 'Secondary education'}
# 0      {'Name': 'Public administration- Other social ...
# 0                         {'Name': 'Tertiary education'}
# 1      {'Name': 'Public administration- Other social ...
#                              ...
# 498      {'Name': 'Agricultural extension and research'}
# 498    {'Name': 'Public administration- Agriculture, ...
# 498      {'Name': 'Agro-industry, marketing, and trade'}
# 499                          {'Name': 'Urban Transport'}
# 499    {'Name': 'Public administration- Transportation'}
# Name: sector, Length: 1405, dtype: object

# %%
sector_values=pd.Series([x.get('Name') for x in sector_series])
sector_values
# Out:
# 0                                       Primary education
# 1                                     Secondary education
# 2            Public administration- Other social services
# 3                                      Tertiary education
# 4            Public administration- Other social services
#                               ...
# 1400                  Agricultural extension and research
# 1401    Public administration- Agriculture, fishing an...
# 1402                  Agro-industry, marketing, and trade
# 1403                                      Urban Transport
# 1404                Public administration- Transportation
# Length: 1405, dtype: object

# %%
project_sector['sector']=sector_values
project_sector.head(5)
# Out:
#                 sector supplementprojectflg projectfinancialtype prodline  \
# 0    Primary education                    N                  IDA       PE
# 0    Primary education                    N                  IDA       PE
# 0    Primary education                    N                  IDA       PE
# 0    Primary education                    N                  IDA       PE
# 1  Secondary education                    N                OTHER       RE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 0                                [Human development]   130000000
# 0                                [Human development]   130000000
# 0                                [Human development]   130000000
# 1  [Economic management, Social protection and ri...           0
#
#                impagency                                       project_name  \
# ...

# %%
top_sectors=project_sector.groupby('sector').count()

# %%
top_ten_sector=top_sectors.sort_values(by='project_name', ascending=False)
top_ten_sector['project_name'].head(10)
# Out:
# sector
# Other social services                               125
# Central government administration                    85
# General agriculture, fishing and forestry sector     81
# Health                                               55
# General public administration sector                 52
# Public administration- Other social services         48
# Sub-national government administration               47
# General industry and trade sector                    41
# Agro-industry, marketing, and trade                  35
# Agricultural extension and research                  35
# Name: project_name, dtype: int64

# %% [markdown]
# ### 3: Find the top 10 major project themes (using column 'mjtheme_namecode')

# %%
world_json.head()
# Out:
#                                               sector supplementprojectflg  \
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
# 2  [{'Name': 'Rural and Inter-Urban Roads and Hig...                    Y
# 3                [{'Name': 'Other social services'}]                    N
# 4  [{'Name': 'General industry and trade sector'}...                    N
#
#   projectfinancialtype prodline  \
# 0                  IDA       PE
# 1                OTHER       RE
# 2                  IDA       PE
# 3                OTHER       RE
# 4                  IDA       PE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 1  [Economic management, Social protection and ri...           0
# 2  [Trade and integration, Public sector governan...     6060000
# ...

# %%
major=world_json['mjtheme_namecode']
major
# Out:
# 0      [{'code': '8', 'name': 'Human development'}, {...
# 1      [{'code': '1', 'name': 'Economic management'},...
# 2      [{'code': '5', 'name': 'Trade and integration'...
# 3      [{'code': '7', 'name': 'Social dev/gender/incl...
# 4      [{'code': '5', 'name': 'Trade and integration'...
#                              ...
# 495    [{'code': '4', 'name': 'Financial and private ...
# 496    [{'code': '8', 'name': 'Human development'}, {...
# 497    [{'code': '10', 'name': 'Rural development'}, ...
# 498    [{'code': '10', 'name': 'Rural development'}, ...
# 499    [{'code': '9', 'name': 'Urban development'}, {...
# Name: mjtheme_namecode, Length: 500, dtype: object

# %%
major_themes=world_json.explode('mjtheme_namecode')
major_themes.head()
# Out:
#                                               sector supplementprojectflg  \
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
# 2  [{'Name': 'Rural and Inter-Urban Roads and Hig...                    Y
#
#   projectfinancialtype prodline  \
# 0                  IDA       PE
# 0                  IDA       PE
# 1                OTHER       RE
# 1                OTHER       RE
# 2                  IDA       PE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 0                                [Human development]   130000000
# 1  [Economic management, Social protection and ri...           0
# ...

# %%
theme_series=major_themes['mjtheme_namecode']
theme_series
# Out:
# 0             {'code': '8', 'name': 'Human development'}
# 0                             {'code': '11', 'name': ''}
# 1           {'code': '1', 'name': 'Economic management'}
# 1      {'code': '6', 'name': 'Social protection and r...
# 2         {'code': '5', 'name': 'Trade and integration'}
#                              ...
# 498          {'code': '10', 'name': 'Rural development'}
# 499           {'code': '9', 'name': 'Urban development'}
# 499           {'code': '8', 'name': 'Human development'}
# 499       {'code': '5', 'name': 'Trade and integration'}
# 499    {'code': '4', 'name': 'Financial and private s...
# Name: mjtheme_namecode, Length: 1499, dtype: object

# %%
theme_names=pd.Series([x.get('name') for x in theme_series])
theme_names
# Out:
# 0                              Human development
# 1
# 2                            Economic management
# 3          Social protection and risk management
# 4                          Trade and integration
#                           ...
# 1494                           Rural development
# 1495                           Urban development
# 1496                           Human development
# 1497                       Trade and integration
# 1498    Financial and private sector development
# Length: 1499, dtype: object

# %%
theme_numbers=pd.Series([x.get('code') for x in theme_series])
theme_numbers
# Out:
# 0        8
# 1       11
# 2        1
# 3        6
# 4        5
#         ..
# 1494    10
# 1495     9
# 1496     8
# 1497     5
# 1498     4
# Length: 1499, dtype: object

# %%
theme=pd.DataFrame()
theme['Numbers']=theme_numbers
theme['Themes']=theme_names
theme.head(10)
# Out:
#   Numbers                                        Themes
# 0       8                             Human development
# 1      11
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion

# %%
theme['Themes'].replace('', np.nan, inplace=True)
theme.dropna(subset=['Themes'], inplace=True)

# %%
theme_dict=theme.drop_duplicates()

# %%
theme_dict = theme_dict.set_index('Numbers')['Themes'].to_dict()
theme_dict
# Out:
# {'8': 'Human development',
#  '1': 'Economic management',
#  '6': 'Social protection and risk management',
#  '5': 'Trade and integration',
#  '2': 'Public sector governance',
#  '11': 'Environment and natural resources management',
#  '7': 'Social dev/gender/inclusion',
#  '4': 'Financial and private sector development',
#  '10': 'Rural development',
#  '9': 'Urban development',
#  '3': 'Rule of law'}

# %%
major_themes['Theme_Num']=theme_numbers
major_themes['Theme_Name']=major_themes['Theme_Num'].map(theme_dict)
major_themes.head()
# Out:
#                                               sector supplementprojectflg  \
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
# 2  [{'Name': 'Rural and Inter-Urban Roads and Hig...                    Y
#
#   projectfinancialtype prodline  \
# 0                  IDA       PE
# 0                  IDA       PE
# 1                OTHER       RE
# 1                OTHER       RE
# 2                  IDA       PE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 0                                [Human development]   130000000
# 1  [Economic management, Social protection and ri...           0
# ...

# %%
top_themes=major_themes.groupby('Theme_Name').count()
top_themes
# Out:
#                                               sector  supplementprojectflg  \
# Theme_Name
# Economic management                               42                    42
# Environment and natural resources management     265                   265
# Financial and private sector development         210                   210
# Human development                                153                   153
# Public sector governance                         239                   239
# Rule of law                                       12                    12
# Rural development                                165                   165
# Social dev/gender/inclusion                      112                   112
# Social protection and risk management            162                   158
# Trade and integration                             94                    94
# Urban development                                 45                    45
#
# ...

# %%
top_ten_themes=top_themes.sort_values(by=['project_name'], ascending=False)
top_ten_themes['project_name'].head(10)
# Out:
# Theme_Name
# Environment and natural resources management    265
# Public sector governance                        239
# Financial and private sector development        210
# Rural development                               165
# Social protection and risk management           162
# Human development                               153
# Social dev/gender/inclusion                     112
# Trade and integration                            94
# Urban development                                45
# Economic management                              42
# Name: project_name, dtype: int64
